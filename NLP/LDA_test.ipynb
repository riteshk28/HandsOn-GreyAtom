# %%
import pandas as pd
import numpy as np
import nltk
from nltk.tokenize import RegexpTokenizer, treebank
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from tqdm import tqdm

# %%
tokenizer = RegexpTokenizer(r'\w+')
en_stop = set(stopwords.words('english'))
p_stemmer = PorterStemmer()

# %%
with open("./LDA_test.txt", "r") as f:
    f1 = f.read()

# %%
sents = f1.split("\n")

# %%
texts = []

# %%
for i in sents:
    
    # clean and tokenize document string
    raw = i.lower()
    tokens = tokenizer.tokenize(raw)
    # remove stop words from tokens
    stopped_tokens = [i for i in tokens if not i in en_stop]
    # stem tokens
    stemmed_tokens = [p_stemmer.stem(i) for i in stopped_tokens]
    # add tokens to list
    texts.append(stemmed_tokens)

# %%
texts[:2]
# Out:
# [['thai', 'polit', 'countri', 'young', 'men'],
#  ['cricket',
#   'religi',
#   'follow',
#   'india',
#   'sometim',
#   'even',
#   'religion',
#   'take',
#   'back',
#   'seat',
#   'come',
#   'unit',
#   'peopl',
#   'cricket']]

# %%
NUM_TOPICS = 3
topic_allocation = []

# %%
for text in texts:
    topic_allocation.append([(i, np.random.randint(NUM_TOPICS)) for i in text])

# %%
topic_allocation
# Out:
# [[('thai', 2), ('polit', 2), ('countri', 1), ('young', 0), ('men', 1)],
#  [('cricket', 1),
#   ('religi', 2),
#   ('follow', 0),
#   ('india', 0),
#   ('sometim', 1),
#   ('even', 2),
#   ('religion', 2),
#   ('take', 0),
#   ('back', 2),
#   ('seat', 2),
#   ('come', 0),
#   ('unit', 1),
#   ('peopl', 0),
#   ('cricket', 0)],
#  [('cricket', 1),
#   ('nation', 2),
#   ('sport', 1),
#   ('play', 2),
#   ('two', 2),
#   ('team', 1),
#   ('eleven', 0),
#   ('player', 1),
#   ('score', 0),
#   ('run', 2),
#   ('point', 2),
#   ('run', 0),
#   ('two', 1),
#   ('set', 2),
#   ('three', 1),
#   ('small', 1),
#   ('wooden', 2),
#   ('post', 0),
#   ('call', 1),
#   ('wicket', 2)],
#  [('england', 0),
#   ('dismiss', 0),
#   ('record', 1),
#   ('low', 1),
#   ('score', 2),
#   ('new', 1),
#   ('zealand', 1),
#   ('home', 1),
#   ('team', 0),
#   ('took', 1),
#   ('cautiou', 2),
#   ('approach', 0),
#   ('led', 0),
#   ('captain', 1),
#   ('kane', 0),
#   ('williamson', 1),
#   ('post', 2),
#   ('18th', 0),
#   ('test', 2),
#   ('centuri', 1),
#   ('new', 0),
#   ('zealand', 2),
#   ('record', 1),
#   ('102', 2)],
#  [('cricket', 2),
#   ('india', 0),
#   ('enthusiast', 1),
#   ('becom', 1),
#   ('religion', 1),
#   ('one', 0),
#   ('reason', 2),
#   ('cricket', 1),
#   ('obsess', 0),
#   ('peopl', 2),
#   ('take', 1),
#   ('religion', 0),
#   ('could', 0),
#   ('greatest', 0),
#   ('batsman', 2),
#   ('cricket', 2),
#   ('histori', 2),
#   ('hail', 1),
#   ('india', 1),
#   ('name', 1),
#   ('sachin', 2),
#   ('tendulkar', 2)],
#  [('cricket', 0), ('circket', 0), ('religion', 2), ('relligion', 2)],
#  [('crick', 0), ('crick', 2), ('cricket', 0), ('throw', 1), ('wicket', 0)],
#  [('lost', 2),
#   ('poll', 2),
#   ('sp', 0),
#   ('bsp', 0),
#   ('reach', 0),
#   ('elector', 1),
#   ('understand', 1),
#   ('last', 0),
#   ('hour', 2)],
#  [('ask', 2),
#   ('bjp', 0),
#   ('elector', 1),
#   ('mathemat', 2),
#   ('could', 0),
#   ('ruin', 1),
#   ('possibl', 2),
#   ('sp', 2),
#   ('bsp', 1),
#   ('allianc', 0),
#   ('2019', 1)],
#  [('cricket', 0), ('also', 2), ('way', 0), ('enter', 2), ('polit', 1)],
#  [('pakistan', 1), ('alway', 1), ('loos', 0), ('play', 0), ('india', 0)],
#  [('ask', 0),
#   ('bjp', 0),
#   ('elector', 0),
#   ('mathemat', 0),
#   ('could', 1),
#   ('ruin', 0),
#   ('possibl', 1),
#   ('sp', 2),
#   ('bsp', 1),
#   ('allianc', 2),
#   ('2019', 1)],
#  [('religion', 2),
#   ('practic', 2),
#   ('cricket', 1),
#   ('cricket', 1),
#   ('religion', 1),
#   ('repli', 1)],
#  [('even', 0),
#   ('though', 2),
#   ('narendra', 2),
#   ('modi', 1),
#   ('politician', 1),
#   ('travel', 1),
#   ('world', 1),
#   ('time', 0),
#   ('never', 1),
#   ('miss', 0),
#   ('singl', 1),
#   ('cricket', 2),
#   ('match', 2),
#   ('india', 0),
#   ('pakistan', 1),
#   ('make', 1),
#   ('sure', 1),
#   ('pakistan', 2),
#   ('loos', 1),
#   ('te', 1),
#   ('time', 1)],
#  [('one', 0),
#   ('way', 0),
#   ('ensur', 2),
#   ('kind', 2),
#   ('homogen', 0),
#   ('enact', 2),
#   ('one', 1),
#   ('form', 2),
#   ('establish', 1),
#   ('mention', 1),
#   ('display', 1),
#   ('religi', 1),
#   ('symbol', 0),
#   ('polit', 1),
#   ('build', 1),
#   ('monument', 2),
#   ('includ', 1),
#   ('refer', 1),
#   ('particular', 2),
#   ('religion', 2),
#   ('polit', 1),
#   ('ceremoni', 1)],
#  [('cricket', 2), ('religion', 1), ('sachin', 1), ('god', 0)],
#  [('india', 1),
#   ('cricket', 2),
#   ('game', 0),
#   ('bona', 2),
#   ('fide', 1),
#   ('religion', 2),
#   ('religion', 0),
#   ('cricket', 0),
#   ('god', 2),
#   ('everi', 1),
#   ('victori', 1),
#   ('festiv', 0)],
#  [('polit', 0), ('good', 1), ('phase', 1), ('today', 2)],
#  [('religion', 1), ('bind', 1), ('human', 2), ('divid', 0)],
#  [('theori', 1),
#   ('polit', 0),
#   ('religion', 1),
#   ('concern', 2),
#   ('government', 1),
#   ('ideolog', 0),
#   ('whose', 1),
#   ('cultur', 2),
#   ('polit', 1),
#   ('back', 2),
#   ('strong', 2),
#   ('said', 1),
#   ('attain', 0),
#   ('power', 2),
#   ('equival', 2),
#   ('state', 0),
#   ('religion', 0),
#   ('often', 1),
#   ('exhibit', 2),
#   ('signific', 0),
#   ('similar', 1),
#   ('theori', 0),
#   ('practic', 0),
#   ('6', 2),
#   ('addit', 0),
#   ('basic', 0),
#   ('form', 0),
#   ('polit', 0),
#   ('like', 0),
#   ('parliament', 1),
#   ('elect', 0),
#   ('also', 0),
#   ('hold', 0),
#   ('aspect', 0),
#   ('sacral', 0),
#   ('relat', 1),
#   ('institut', 0),
#   ('contain', 0),
#   ('within', 0),
#   ('regim', 0),
#   ('also', 0),
#   ('provid', 1),
#   ('inner', 0),
#   ('measur', 2),
#   ('tradit', 2),
#   ('consid', 0),
#   ('religi', 2),
#   ('territori', 0),
#   ('ethic', 1),
#   ('valu', 0),
#   ('symbol', 1),
#   ('myth', 0),
#   ('ritual', 0),
#   ('exampl', 0),
#   ('nation', 1),
#   ('liturg', 1),
#   ('calendar', 2),
#   ('polit', 1),
#   ('good', 1),
#   ('phase', 0),
#   ('today', 1)],
#  [('blast', 1),
#   ('one', 1),
#   ('cover', 0),
#   ('1st', 1),
#   ('cricket', 2),
#   ('match', 2),
#   ('cricket', 2),
#   ('cricket', 1),
#   ('hurray', 0)],
#  [('let', 0),
#   ('predict', 1),
#   ('win', 0),
#   ('2019', 2),
#   ('elect', 1),
#   ('polit', 1),
#   ('pandit', 0)],
#  [('religion', 2),
#   ('bind', 1),
#   ('human', 0),
#   ('divid', 1),
#   ('god', 0),
#   ('cricket', 2),
#   ('like', 2),
#   ('religion', 2),
#   ('cricket', 1),
#   ('unit', 1),
#   ('us', 2),
#   ('like', 0),
#   ('differ', 1),
#   ('religion', 0),
#   ('india', 0)],
#  [('india', 2),
#   ('countri', 1),
#   ('cricket', 2),
#   ('religion', 0),
#   ('ipl', 0),
#   ('biggest', 2),
#   ('cricket', 1),
#   ('event', 0),
#   ('world', 2)],
#  [('pakistan', 2), ('alway', 2), ('loos', 0), ('play', 0), ('india', 1)]]

# %%
def df_generator(topic_allocation):    
    token_list = []
    topic_list = []
    doc_list = []
    for i, text in enumerate(topic_allocation):
        for token in text:
            topic_list.append(token[1])
            token_list.append(token[0])
            doc_list.append(i)
    return pd.DataFrame({"token": token_list, "topic_no": topic_list, "doc_no": doc_list})

# %%
def token_dist_maker(df):   
    token_dist = df.pivot_table(values=["topic_no"], index=["token"], columns=["topic_no"], aggfunc="count")
    token_dist.reset_index(inplace=True)
    token_dist.columns = ['token', 'grp_1', 'grp_2', 'grp_3']
    token_dist.fillna(0.01 , inplace=True)
    return token_dist

# %%
def doc_dist_maker(df):    
    doc_dist = df.pivot_table(values=["topic_no"], index=["doc_no"], columns=["topic_no"], aggfunc="count")
    doc_dist.reset_index(inplace=True)
    doc_dist.columns = ['doc_no', 'grp_1', 'grp_2', 'grp_3']
    doc_dist.fillna(0.01 , inplace=True)
    return doc_dist

# %%
df_generator(topic_allocation).head()
# Out:
#    doc_no    token  topic_no
# 0       0     thai         2
# 1       0    polit         2
# 2       0  countri         1
# 3       0    young         0
# 4       0      men         1

# %%
token_dist_0 = token_dist_maker(df_generator(topic_allocation))
token_dist_0.head(10)
# Out:
#       token  grp_1  grp_2  grp_3
# 0       102   0.01   0.01   1.00
# 1      18th   1.00   0.01   0.01
# 2       1st   0.01   1.00   0.01
# 3      2019   0.01   2.00   1.00
# 4         6   0.01   0.01   1.00
# 5     addit   1.00   0.01   0.01
# 6   allianc   1.00   0.01   1.00
# 7      also   2.00   0.01   1.00
# 8     alway   0.01   1.00   1.00
# 9  approach   1.00   0.01   0.01

# %%
doc_dist_0 = doc_dist_maker(df_generator(topic_allocation))
doc_dist_0.head(10)
# Out:
#    doc_no  grp_1  grp_2  grp_3
# 0       0    1.0   2.00    2.0
# 1       1    6.0   3.00    5.0
# 2       2    4.0   8.00    8.0
# 3       3    8.0  10.00    6.0
# 4       4    6.0   8.00    8.0
# 5       5    2.0   0.01    2.0
# 6       6    3.0   1.00    1.0
# 7       7    4.0   2.00    3.0
# 8       8    3.0   4.00    4.0
# 9       9    2.0   1.00    2.0

# %%
ITER = 10
doc_dist = doc_dist_0.copy()
token_dist = token_dist_0.copy()

# %%
for num in tqdm(range(ITER)):
    for doc_number, sent in enumerate(topic_allocation):
        t1_freq = doc_dist.loc[(doc_dist.doc_no == doc_number), "grp_1"].values[0]
        t2_freq = doc_dist.loc[(doc_dist.doc_no == doc_number), "grp_2"].values[0]
        t3_freq = doc_dist.loc[(doc_dist.doc_no == doc_number), "grp_3"].values[0]
        for i, (token, topic) in enumerate(sent):
            p1_freq = token_dist.loc[token_dist.token == token, "grp_1"].values[0]
            p2_freq = token_dist.loc[token_dist.token == token, "grp_2"].values[0]
            p3_freq = token_dist.loc[token_dist.token == token, "grp_3"].values[0]
            
            p1t1 = t1_freq * p1_freq
            p2t2 = t2_freq * p2_freq
            p3t3 = t3_freq * p3_freq  
            total = p1t1 + p2t2 + p3t3
            
            p_p1t1 = p1t1/total
            p_p2t2 = p2t2/total
            p_p3t3 = p3t3/total
            
            topic = np.random.choice([0, 1, 2], p=[p_p1t1, p_p2t2, p_p3t3])
            topic_allocation[doc_number][i] = (token, topic)
            
            token_dist = token_dist_maker(df_generator(topic_allocation))
            doc_dist = doc_dist_maker(df_generator(topic_allocation))
# Out:
# 100%|██████████| 10/10 [01:55<00:00, 11.59s/it]

# %%
# token_dist = token_dist_maker(df_generator(topic_allocation))
token_dist.head(10)
# Out:
#       token  grp_1  grp_2  grp_3
# 0       102   0.01   1.00   0.01
# 1      18th   0.01   0.01   1.00
# 2       1st   0.01   1.00   0.01
# 3      2019   0.01   3.00   0.01
# 4         6   1.00   0.01   0.01
# 5     addit   1.00   0.01   0.01
# 6   allianc   2.00   0.01   0.01
# 7      also   0.01   3.00   0.01
# 8     alway   0.01   0.01   2.00
# 9  approach   1.00   0.01   0.01

# %%
# doc_dist = doc_dist_maker(df_generator(topic_allocation))
doc_dist.head(20)
# Out:
#     doc_no  grp_1  grp_2  grp_3
# 0        0   2.00   0.01   3.00
# 1        1   3.00  10.00   1.00
# 2        2   6.00   5.00   9.00
# 3        3   9.00   7.00   8.00
# 4        4   9.00  13.00   0.01
# 5        5   1.00   3.00   0.01
# 6        6   2.00   3.00   0.01
# 7        7   2.00   7.00   0.01
# 8        8   4.00   7.00   0.01
# 9        9   0.01   5.00   0.01
# 10      10   2.00   0.01   3.00
# 11      11   4.00   7.00   0.01
# 12      12   0.01   6.00   0.01
# 13      13   9.00  10.00   2.00
# 14      14   1.00  16.00   5.00
# 15      15   1.00   3.00   0.01
# 16      16   0.01  12.00   0.01
# 17      17   1.00   3.00   0.01
# 18      18   0.01   4.00   0.01
# 19      19  13.00  37.00  11.00

# %%
sents[19]
# Out:
# 'The theory of political religion concerns governmental ideologies whose cultural and political backing is so strong that they are said to attain power equivalent to those of a state religion, with which they often exhibit significant similarities in both theory and practice.[6] In addition to basic forms of politics, like parliament and elections, it also holds an aspect of sacralization related to the institutions contained within the regime and also provides the inner measures traditionally considered to be religious territory, such as ethics, values, symbols, myths, rituals and for example a national liturgical calendar.Politics is in good phase today. '

# %%
doc_dist_0.head(10)
# Out:
#    doc_no  grp_1  grp_2  grp_3
# 0       0    2.0    2.0    1.0
# 1       1    5.0    5.0    4.0
# 2       2    7.0    6.0    7.0
# 3       3   10.0    5.0    9.0
# 4       4   13.0    6.0    3.0
# 5       5    1.0    2.0    1.0
# 6       6    1.0    2.0    2.0
# 7       7    2.0    6.0    1.0
# 8       8    2.0    4.0    5.0
# 9       9    2.0    2.0    1.0
